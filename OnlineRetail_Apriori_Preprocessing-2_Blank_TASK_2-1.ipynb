# %% [markdown]
# # 🧺 Online Retail Dataset (Apriori Preprocessing) - TASK 2
# **Dataset**: https://www.kaggle.com/datasets/vijayuv/onlineretail

# %% [markdown]
# # Step 1: Load Data

# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_csv('OnlineRetail.csv',encoding='ISO-8859-1')
data
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#             InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %% [markdown]
# # Step 2: Drop Missing Invoices or Descriptions

# %%
data1=data.copy()
data1.dropna(subset=['InvoiceNo'], inplace=True)
data1
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#             InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
data2=data.copy()
data2.dropna(subset=['Description'], inplace=True)
data2
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#             InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %% [markdown]
# # Step 3: Remove Canceled Invoices <BR> Start with letter 'c'

# %%
data3 = data.copy()
data3 = data3[~data3['InvoiceNo'].str.startswith('C')]
data3
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#             InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %% [markdown]
# # Step 4: Keep Only Positive Quantities

# %%
data4 = data.copy()
data4 = data4[data4['Quantity'] > 0]
data4
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#             InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %% [markdown]
# # Step 5: Standardize Item Descriptions | Lower case and remove space

# %%
data5 = data.copy()
data5['Description'] = data5['Description'].str.lower().str.replace(' ', '', regex=False)
data5
# Out:
#        InvoiceNo StockCode                     Description  Quantity  \
# 0         536365    85123A  whitehangingheartt-lightholder         6
# 1         536365     71053               whitemetallantern         6
# 2         536365    84406B      creamcupidheartscoathanger         8
# 3         536365    84029G  knittedunionflaghotwaterbottle         6
# 4         536365    84029E      redwoollyhottiewhiteheart.         6
# ...          ...       ...                             ...       ...
# 541904    581587     22613         packof20spaceboynapkins        12
# 541905    581587     22899        children'saprondollygirl         6
# 541906    581587     23254       childrenscutlerydollygirl         4
# 541907    581587     23255    childrenscutlerycircusparade         4
# 541908    581587     22138        bakingset9pieceretrospot         3
#
#             InvoiceDate  UnitPrice  CustomerID         Country
# 0        12/1/2010 8:26       2.55     17850.0  United Kingdom
# ...

# %% [markdown]
# # Step 6: Filter for a Single Country (e.g., United Kingdom)

# %%
data6 = data.copy()
data6 = data6[data6['Country'] == 'United Kingdom']
data6
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541889    581585     22466       FAIRY TALE COTTAGE NIGHT LIGHT        12
# 541890    581586     22061  LARGE CAKE STAND  HANGING STRAWBERY         8
# 541891    581586     23275     SET OF 3 HANGING OWLS OLLIE BEAK        24
# 541892    581586     21217        RED RETROSPOT ROUND CAKE TINS        24
# 541893    581586     20685                DOORMAT RED RETROSPOT        10
#
#             InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %% [markdown]
# # Step 7: Remove Duplicates

# %%
data7 = data.copy()
data7 = data7.drop_duplicates()
data7
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#             InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %% [markdown]
# # Step 8: Add TotalPrice column , TotalPrice = Quantity *  UnitPrice

# %%
data8 = data.copy()
data8['TotalPrice'] = data8['Quantity'] * data8['UnitPrice']
data8
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#             InvoiceDate  UnitPrice  CustomerID         Country  TotalPrice
# ...

# %% [markdown]
# # Step 9 : Check for Top 10 Selling Products

# %%
data9 = data.copy()
top_products = data9.groupby('Description')['Quantity'].sum().sort_values(ascending=False).head(10)
print(top_products)
# Out:
# Description
# WORLD WAR 2 GLIDERS ASSTD DESIGNS     53847
# JUMBO BAG RED RETROSPOT               47363
# ASSORTED COLOUR BIRD ORNAMENT         36381
# POPCORN HOLDER                        36334
# PACK OF 72 RETROSPOT CAKE CASES       36039
# WHITE HANGING HEART T-LIGHT HOLDER    35317
# RABBIT NIGHT LIGHT                    30680
# MINI PAINT SET VINTAGE                26437
# PACK OF 12 LONDON TISSUES             26315
# PACK OF 60 PINK PAISLEY CAKE CASES    24753
# Name: Quantity, dtype: int64

# %% [markdown]
# # Step 10 : Identify Most Active Customers

# %%
data10 = data.copy()
active_customers_qty = (
    data10.groupby('CustomerID')['Quantity']
    .sum()
    .sort_values(ascending=False)
    .head(10)
)

print(active_customers_qty)
# Out:
# CustomerID
# 14646.0    196719
# 12415.0     77242
# 14911.0     77180
# 17450.0     69029
# 18102.0     64122
# 17511.0     63012
# 13694.0     61803
# 14298.0     58021
# 14156.0     57025
# 16684.0     49390
# Name: Quantity, dtype: int64

# %% [markdown]
# # Step 11: Time-Based Analysis | Convert InvoiceDate to datetime and check popular months/hours.

# %%
data11= data.copy()
data11['InvoiceDate'] = pd.to_datetime(data11['InvoiceDate'])
data11['Month'] = data11['InvoiceDate'].dt.month
data11['Hour'] = data11['InvoiceDate'].dt.hour
popular_months = data11['Month'].value_counts().sort_index()
print(popular_months)
popular_hours = data11['Hour'].value_counts().sort_index()
print(popular_hours)


import matplotlib.pyplot as plt

# Plot popular months
popular_months.plot(kind='bar', title='Popular Months')
plt.xlabel('Month')
plt.ylabel('Number of Transactions')
plt.show()

# Plot popular hours
popular_hours.plot(kind='bar', title='Popular Hours')
plt.xlabel('Hour of Day')
plt.ylabel('Number of Transactions')
plt.show()
# Out:
# Month
# 1     35147
# 2     27707
# 3     36748
# 4     29916
# 5     37030
# 6     36874
# 7     39518
# 8     35284
# 9     50226
# 10    60742
# 11    84711
# 12    68006
# Name: count, dtype: int64
# Hour
# 6        41
# 7       383
# 8      8909
# 9     34332
# 10    49037
# 11    57674
# 12    78709
# 13    72259
# 14    67471
# 15    77519
# 16    54516
# 17    28509
# 18     7974
# 19     3705
# 20      871
# Name: count, dtype: int64

# %% [markdown]
# # Step 12: Convert to Basket Format

# %% [markdown]
# Example
# <table border="1">
#     <thead>
#         <tr>
#             <th>Transaction</th>
#             <th>Milk</th>
#             <th>Bread</th>
#             <th>Butter</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr><td>T1</td><td>1</td><td>1</td><td>1</td></tr>
#         <tr><td>T2</td><td>0</td><td>1</td><td>1</td></tr>
#         <tr><td>T3</td><td>1</td><td>0</td><td>0</td></tr>
#         <tr><td>T4</td><td>1</td><td>1</td><td>0</td></tr>
#         <tr><td>T5</td><td>0</td><td>1</td><td>1</td></tr>
#     </tbody>
# </table>

# %%
# Out:
# Description  *boombox ipod classic  *usb office mirror ball  \
# InvoiceNo
# 536365                           0                        0
# 536366                           0                        0
# 536367                           0                        0
# 536368                           0                        0
# 536369                           0                        0
# ...                            ...                      ...
# 581585                           0                        0
# 581586                           0                        0
# A563185                          0                        0
# A563186                          0                        0
# A563187                          0                        0
#
# Description  10 colour spaceboy pen  12 coloured party balloons  \
# InvoiceNo
# 536365                            0                           0
# 536366                            0                           0
# ...

# %% [markdown]
# # Step:13 : Save Basket Format into CSV file
